# %%
! pip install gradio
# !pip install ultralytics
# Out:
# ...
#   Preparing metadata (setup.py) ... done
# ...
#   Using cached Jinja2-3.1.3-py3-none-any.whl.metadata (3.3 kB)
# ...
#   Using cached matplotlib-3.8.2-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (5.8 kB)
# ...
#   Using cached numpy-1.26.4-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (61 kB)
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 49.4/49.4 kB 792.0 kB/s eta 0:00:00a 0:00:01
# ...
#   Using cached pandas-2.2.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (19 kB)
# ...
#   Using cached pillow-10.2.0-cp310-cp310-manylinux_2_28_x86_64.whl.metadata (9.7 kB)
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 83.5/83.5 kB 490.4 kB/s eta 0:00:0000:0100:01
# ...
#   Using cached PyYAML-6.0.1-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (2.1 kB)
# ...
#   Using cached typing_extensions-4.9.0-py3-none-any.whl.metadata (3.0 kB)
# ...
#   Using cached fsspec-2024.2.0-py3-none-any.whl.metadata (6.8 kB)
# ...

# %%
# !pip install ultralytics
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...
#   Using cached ultralytics-8.1.11-py3-none-any.whl (709 kB)
# ...
#   Using cached scipy-1.12.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (38.4 MB)
# ...
#   Using cached torch-2.2.0-cp310-cp310-manylinux1_x86_64.whl (755.5 MB)
# ...
#   Using cached torchvision-0.17.0-cp310-cp310-manylinux1_x86_64.whl (6.9 MB)
# ...
#   Using cached py_cpuinfo-9.0.0-py3-none-any.whl (22 kB)
# ...
#   Using cached seaborn-0.13.2-py3-none-any.whl (294 kB)
# ...
#   Using cached thop-0.1.1.post2209072238-py3-none-any.whl (15 kB)
# ...
#   Using cached opencv_python-4.9.0.80-cp37-abi3-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (62.2 MB)
# ...
#   Using cached nvidia_cufft_cu12-11.0.2.54-py3-none-manylinux1_x86_64.whl (121.6 MB)
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.6/1.6 MB 4.6 MB/s eta 0:00:00a 0:00:01
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.5/56.5 MB 5.6 MB/s eta 0:00:0000:0100:01
# ...

# %% [markdown]
# # Actual detection code

# %%
import sys

sys.path.append("./yolov5")

from detect import run

model = YOLO("/media/yashas/Whatev/project/smoke_detector/gradio_app/smoke_detection.pt")

import cv2
import torch
import os

def detect_objects_framewise(video):

    print (type(video))

    cap = cv2.VideoCapture(video)

    print (cap)

    while cap.isOpened():
        ret, frame = cap.read()


        print ("Running YOLO")

        print (ret)

        if not ret:
            break

        results = model.predict(frame, save=True)

        print (results)

        results.append(frame)

    cap.release()

    return results

def detect_objects_videowise(video):

  result = model.predict(source=video, save=True, name="result_video", verbose = False)

  files = os.listdir(result[0].save_dir)

  return os.path.join(result[0].save_dir, files[0])
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[5], line 5
#       1 import sys
#       3 sys.path.append("./yolov5")
# ----> 5 from detect import run
#       7 model = YOLO("/media/yashas/Whatev/project/smoke_detector/gradio_app/smoke_detection.pt")
#       9 import cv2
#
# File /media/yashas/Whatev/project/smoke_detector/gradio_app/./yolov5/detect.py:38
#      35 import sys
#      36 from pathlib import Path
# ---> 38 import torch
#      40 FILE = Path(__file__).resolve()
#      41 ROOT = FILE.parents[0]  # YOLOv5 root directory
#
# ModuleNotFoundError: No module named 'torch'

# %%
detect_objects_videowise("/content/drive/MyDrive/colab/obj_detection_from_drone/input/bomb.mp4")
# Out:
# WARNING ⚠️ inference results will accumulate in RAM unless `stream=True` is passed, causing potential out-of-memory
# errors for large sources or long-running streams and videos. See https://docs.ultralytics.com/modes/predict/ for help.
#
# Example:
#     results = model(source=..., stream=True)  # generator of Results objects
#     for r in results:
#         boxes = r.boxes  # Boxes object for bbox outputs
#         masks = r.masks  # Masks object for segment masks outputs
#         probs = r.probs  # Class probabilities for classification outputs
#
# Results saved to runs/detect/result_video2
# 'runs/detect/result_video2/bomb.avi'

# %% [markdown]
# Gradio interface

# %%
import gradio as gr

iface = gr.Interface(
    detect_objects_videowise,

    gr.Video(),

    examples = ['/content/drive/MyDrive/colab/obj_detection_from_drone/input/bomb.mp4', ]

    cache_examples=True,

    outputs="playable_video",

    title = "Smoke detection from drone video"
)

iface.launch()
# Out:
#   File "<ipython-input-12-e6ca51419325>", line 8
#     examples = ['/content/drive/MyDrive/colab/obj_detection_from_drone/input/bomb.mp4', ]
#                ^
# SyntaxError: invalid syntax. Perhaps you forgot a comma?
